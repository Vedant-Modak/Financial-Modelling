# %% [markdown]
# **Vedant Modak**
#   | BE(IT) undergrad @ PES Modern College of Engineering,Pune.

# %% [markdown]
# **Monte-Carlo Simulation for Financial Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
rev_m=170  #revenue mean(revenue in millions)
rev_std=20
iterations=1000

# %%
rev=np.random.normal(rev_m, rev_std, iterations)
rev
# Out:
# array([148.23814222, 152.7093486 , 154.34935894, 168.05832826,
#        169.80188976, 144.1245638 , 169.21488895, 177.7078068 ,
#        185.83359359, 165.5540476 , 150.38694197, 171.55925759,
#        171.30168319, 184.01235977, 170.8311395 , 207.72181912,
#        194.49321892, 158.91215107, 150.03697477, 197.34295329,
#        158.11507852, 146.4781497 , 154.63432977, 156.19364702,
#        158.35555503, 149.49158133, 207.55897186, 152.08948839,
#        137.02969443, 151.05130242, 177.36405504, 181.31450109,
#        152.21375187, 167.87457855, 158.21645354, 129.25864789,
#        201.88800729, 159.57613553, 190.78869417, 185.06091969,
#        197.09909195, 191.82084784, 181.22474661, 187.77256909,
#        179.95398937, 187.37627894, 180.82124512, 146.36248961,
#        166.52170922, 163.27338131, 158.74766275, 175.43909671,
#        177.91492045, 146.52073804, 171.27509846, 148.46236548,
#        139.33837698, 189.94446327, 166.64919947, 159.16395651,
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(rev)
plt.show()

# %%
COGS = -(rev*np.random.normal(0.6, 0.1))  #Cost of Goods(COGS) Considering COGS is 60% of revenue

plt.figure(figsize=(15,6))
plt.plot(COGS)
plt.show()

# %%
COGS.mean()
# Out:
# -112.73017740548975

# %%
COGS.std()
# Out:
# 13.565524418977159

# %%
Gross_Profit= rev+COGS
Gross_Profit


plt.figure(figsize=(15,6))
plt.plot(Gross_Profit)
plt.show()

# %%
max(Gross_Profit)
# Out:
# 82.12290025875745

# %%
min(Gross_Profit)
# Out:
# 36.494206224279395

# %%
Gross_Profit.mean()
# Out:
# 57.25738337385651

# %%
Gross_Profit.std()
# Out:
# 6.89013758517302

# %%
plt.figure(figsize=(15,8))
plt.hist(Gross_Profit, bins=[40,50,60,70,80,90])
plt.show()
